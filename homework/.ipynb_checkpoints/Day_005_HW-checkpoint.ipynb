# %%
import os
import numpy as np
import pandas as pd

# %%
curr_dir = os.getcwd()
f_app_train = os.path.join(curr_dir, '../data/application_train.csv')
f_app_test = os.path.join(curr_dir, '../data/application_test.csv')

app_train = pd.read_csv(f_app_train)
app_test = pd.read_csv(f_app_test)

# %%
for col, row in app_test.items():
#     print(col, row)
    print(col, row[:5])
# Out:
# SK_ID_CURR 0    100001
# 1    100005
# 2    100013
# 3    100028
# 4    100038
# Name: SK_ID_CURR, dtype: int64
# NAME_CONTRACT_TYPE 0    Cash loans
# 1    Cash loans
# 2    Cash loans
# 3    Cash loans
# 4    Cash loans
# Name: NAME_CONTRACT_TYPE, dtype: object
# CODE_GENDER 0    F
# 1    M
# 2    M
# 3    F
# 4    M
# Name: CODE_GENDER, dtype: object
# FLAG_OWN_CAR 0    N
# 1    N
# 2    Y
# 3    N
# 4    Y
# Name: FLAG_OWN_CAR, dtype: object
# FLAG_OWN_REALTY 0    Y
# 1    Y
# 2    Y
# 3    Y
# 4    N
# Name: FLAG_OWN_REALTY, dtype: object
# CNT_CHILDREN 0    0
# 1    0
# 2    0
# 3    2
# 4    1
# Name: CNT_CHILDREN, dtype: int64
# AMT_INCOME_TOTAL 0    135000.0
# 1     99000.0
# 2    202500.0
# 3    315000.0
# 4    180000.0
# Name: AMT_INCOME_TOTAL, dtype: float64
# AMT_CREDIT 0     568800.0
# 1     222768.0
# 2     663264.0
# 3    1575000.0
# 4     625500.0
# Name: AMT_CREDIT, dtype: float64
# AMT_ANNUITY 0    20560.5
# 1    17370.0
# 2    69777.0
# 3    49018.5
# 4    32067.0
# ...

# %%
import matplotlib.pyplot as plt

n_bins = 100
fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)
axs[0].hist(app_train['AMT_REQ_CREDIT_BUREAU_YEAR'], bins=n_bins)
# Out:
# (array([7.1801e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 6.3405e+04,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 5.0192e+04, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 3.3628e+04, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 2.0714e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.2052e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 6.9670e+03,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 3.8690e+03, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 2.1270e+03, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 1.0960e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         2.2000e+01, 0.0000e+00, 0.0000e+00, 0.0000e+00, 3.1000e+01,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 3.0000e+01, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 1.9000e+01, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 1.0000e+01, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         6.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 3.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 7.0000e+00, 0.0000e+00,
# ...
